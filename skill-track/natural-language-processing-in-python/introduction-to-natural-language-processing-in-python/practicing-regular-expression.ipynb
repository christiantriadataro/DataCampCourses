# %% [markdown]
# ## Exercise: Practicing regular expressions: re.split() and re.findall()

# %% [markdown]
# ### Regular expressions & word tokenization

# %%
import re
my_string = "Let's write RegEx!  Won't that be fun?  I sure think so.  Can you find 4 sentences?  Or perhaps, all 19 words?"

# %% [markdown]
# - Split `my_string` on each sentence ending. To do this:
#     - Write a pattern called `sentence_endings` to match sentence endings (`.?!`).
#     - Use `re.split()` to split `my_string` on the pattern and print the result.

# %%
# Write a pattern to mach sentence endings:
sentence_endings = r"[.?!]"
display(re.split(sentence_endings, my_string))
# Out:
# ["Let's write RegEx",
#  "  Won't that be fun",
#  '  I sure think so',
#  '  Can you find 4 sentences',
#  '  Or perhaps, all 19 words',
#  '']

# %% [markdown]
# - Find and print all capitalized words in `my_string` by writing a pattern called `capitalized_words` and using `re.findall()`.
#     - Remember the `[a-z] pattern shown in the video to match lowercase groups? Modify that pattern appropriately in order to match uppercase groups.

# %%
capitalized_words = r"[A-Z]\w+"
display(re.findall(capitalized_words, my_string))
# Out:
# ['Let', 'RegEx', 'Won', 'Can', 'Or']

# %%
spaces = r"\s+"
display(re.split(spaces, my_string))
# Out:
# ["Let's",
#  'write',
#  'RegEx!',
#  "Won't",
#  'that',
#  'be',
#  'fun?',
#  'I',
#  'sure',
#  'think',
#  'so.',
#  'Can',
#  'you',
#  'find',
#  '4',
#  'sentences?',
#  'Or',
#  'perhaps,',
#  'all',
#  '19',
#  'words?']

# %%
digits = r"\d+"
display(re.findall(digits, my_string))
# Out:
# ['4', '19']
